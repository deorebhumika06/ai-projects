# %% [markdown]
# <a href="https://colab.research.google.com/github/deorebhumika06/ai-projects/blob/main/logical%26%20decision%20tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv('/content/train_u6lujuX_CVtuZ9i (1).csv')
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
numerical_cols_to_impute = ['LoanAmount', 'Loan_Amount_Term']
categorical_cols_to_impute = ['Gender', 'Married', 'Dependents', 'Self_Employed', 'Credit_History']

for col in numerical_cols_to_impute:
    median_val = df[col].median()
    df[col].fillna(median_val, inplace=True)
    print(f"Missing values in '{col}' filled with median: {median_val}")

for col in categorical_cols_to_impute:
    mode_val = df[col].mode()[0] # .mode() returns a Series, so take the first element
    df[col].fillna(mode_val, inplace=True)
    print(f"Missing values in '{col}' filled with mode: {mode_val}")

# Verify no missing values remain
print("\nVerifying remaining missing values:")
print(df.isnull().sum())
# Out:
# Missing values in 'LoanAmount' filled with median: -0.20736415876449873
# Missing values in 'Loan_Amount_Term' filled with median: 0.27985054320228187
# Missing values in 'Gender' filled with mode: 1
# Missing values in 'Married' filled with mode: 1
# Missing values in 'Dependents' filled with mode: 0
# Missing values in 'Self_Employed' filled with mode: 0
# Missing values in 'Credit_History' filled with mode: 1.0
#
# Verifying remaining missing values:
# Gender                     0
# Married                    0
# Dependents                 0
# Education                  0
# Self_Employed              0
# ApplicantIncome            0
# CoapplicantIncome          0
# LoanAmount                 0
# Loan_Amount_Term           0
# Credit_History             0
# Loan_Status                0
# Property_Area_Semiurban    0
# Property_Area_Urban        0
# dtype: int64
# ...

# %%
numerical_cols_to_impute = ['LoanAmount', 'Loan_Amount_Term']
categorical_cols_to_impute = ['Gender', 'Married', 'Dependents', 'Self_Employed', 'Credit_History']

for col in numerical_cols_to_impute:
    median_val = df[col].median()
    df[col] = df[col].fillna(median_val)
    print(f"Missing values in '{col}' filled with median: {median_val}")

for col in categorical_cols_to_impute:
    mode_val = df[col].mode()[0] # .mode() returns a Series, so take the first element
    df[col] = df[col].fillna(mode_val)
    print(f"Missing values in '{col}' filled with mode: {mode_val}")

# Verify no missing values remain
print("\nVerifying remaining missing values:")
print(df.isnull().sum())
# Out:
# Missing values in 'LoanAmount' filled with median: -0.20736415876449873
# Missing values in 'Loan_Amount_Term' filled with median: 0.27985054320228187
# Missing values in 'Gender' filled with mode: 1
# Missing values in 'Married' filled with mode: 1
# Missing values in 'Dependents' filled with mode: 0
# Missing values in 'Self_Employed' filled with mode: 0
# Missing values in 'Credit_History' filled with mode: 1.0
#
# Verifying remaining missing values:
# Gender                     0
# Married                    0
# Dependents                 0
# Education                  0
# Self_Employed              0
# ApplicantIncome            0
# CoapplicantIncome          0
# LoanAmount                 0
# Loan_Amount_Term           0
# Credit_History             0
# Loan_Status                0
# Property_Area_Semiurban    0
# Property_Area_Urban        0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

numerical_features = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']

scaler = StandardScaler()
df[numerical_features] = scaler.fit_transform(df[numerical_features])

print("Numerical features scaled successfully:")
print(df[numerical_features].head())
# Out:
# Numerical features scaled successfully:
#    ApplicantIncome  CoapplicantIncome    LoanAmount  Loan_Amount_Term
# 0         0.072991          -0.554487 -5.786179e-18          0.279851
# 1        -0.134412          -0.038732 -2.192733e-01          0.279851
# 2        -0.393747          -0.554487 -9.576410e-01          0.279851
# 3        -0.462062           0.251980 -3.145466e-01          0.279851
# 4         0.097728          -0.554487 -6.445428e-02          0.279851

# %%
import pandas as pd
df=pd.read_csv('/content/train_u6lujuX_CVtuZ9i (1).csv')
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_cols_to_visualize = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']

for col in numerical_cols_to_visualize:
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    # Histogram
    sns.histplot(data=df, x=col, kde=True, ax=axes[0])
    axes[0].set_title(f'Histogram of {col}')

    # Box Plot
    sns.boxplot(data=df, x=col, ax=axes[1])
    axes[1].set_title(f'Box Plot of {col}')

    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numerical_features_to_plot = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount']

for col in numerical_features_to_plot:
    plt.figure(figsize=(10, 6))
    sns.boxplot(data=df, x='Loan_Status', y=col)
    plt.title(f'Box Plot of {col} vs. Loan_Status')
    plt.xlabel('Loan Status')
    plt.ylabel(col)
    plt.show()

# %%
numerical_cols_to_impute = ['LoanAmount', 'Loan_Amount_Term']
categorical_cols_to_impute = ['Gender', 'Married', 'Dependents', 'Self_Employed', 'Credit_History']

for col in numerical_cols_to_impute:
    median_val = df[col].median()
    df[col] = df[col].fillna(median_val)
    print(f"Missing values in '{col}' filled with median: {median_val}")

for col in categorical_cols_to_impute:
    mode_val = df[col].mode()[0] # .mode() returns a Series, so take the first element
    df[col] = df[col].fillna(mode_val)
    print(f"Missing values in '{col}' filled with mode: {mode_val}")

# Verify no missing values remain
print("\nVerifying remaining missing values:")
print(df.isnull().sum())
# Out:
# Missing values in 'LoanAmount' filled with median: 128.0
# Missing values in 'Loan_Amount_Term' filled with median: 360.0
# Missing values in 'Gender' filled with mode: Male
# Missing values in 'Married' filled with mode: Yes
# Missing values in 'Dependents' filled with mode: 0
# Missing values in 'Self_Employed' filled with mode: No
# Missing values in 'Credit_History' filled with mode: 1.0
#
# Verifying remaining missing values:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df['Loan_Status'] = df['Loan_Status'].map({'Y': 1, 'N': 0})
df['Gender'] = df['Gender'].map({'Male': 1, 'Female': 0})
df['Married'] = df['Married'].map({'Yes': 1, 'No': 0})
df['Education'] = df['Education'].map({'Graduate': 0, 'Not Graduate': 1})
df['Self_Employed'] = df['Self_Employed'].map({'Yes': 1, 'No': 0})

df['Dependents'] = df['Dependents'].replace('3+', '3').astype(int)

df = pd.get_dummies(df, columns=['Property_Area'], drop_first=True)

print("Categorical features encoded successfully.")
print(df.head())
# Out:
# Categorical features encoded successfully.
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0  LP001002       1        0           0          0              0
# 1  LP001003       1        1           1          0              0
# 2  LP001005       1        1           0          0              1
# 3  LP001006       1        1           0          1              0
# 4  LP001008       1        0           0          0              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History  Loan_Status  Property_Area_Semiurban  Property_Area_Urban
# ...

# %%
if 'Loan_ID' in df.columns:
    df = df.drop('Loan_ID', axis=1)
    print("Dropped 'Loan_ID' column.")

X = df.drop('Loan_Status', axis=1)
y = df['Loan_Status']

print("Features (X) and Target (y) prepared.")
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
print("First 5 rows of X:")
print(X.head())
print("First 5 rows of y:")
print(y.head())
# Out:
# Dropped 'Loan_ID' column.
# Features (X) and Target (y) prepared.
# Shape of X: (614, 12)
# Shape of y: (614,)
# First 5 rows of X:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0           0          0              0             5849
# 1       1        1           1          0              0             4583
# 2       1        1           0          0              1             3000
# 3       1        1           0          1              0             2583
# 4       1        0           0          0              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       128.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

# Initialize the Decision Tree Classifier
dtc = DecisionTreeClassifier(random_state=42)

# Train the model using the training data
dtc.fit(X_train, y_train)

print("Decision Tree Classifier trained successfully.")
# Out:
# Decision Tree Classifier trained successfully.

# %%
y_pred = dtc.predict(X_test)
y_pred_proba = dtc.predict_proba(X_test)[:, 1]

print("Predictions on the test set:")
print(y_pred[:5])
print("Predicted probabilities (positive class) on the test set:")
print(y_pred_proba[:5])
# Out:
# Predictions on the test set:
# [1 1 1 0 1]
# Predicted probabilities (positive class) on the test set:
# [1. 1. 1. 0. 1.]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, roc_auc_score

# Calculate evaluation metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred_proba)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-Score: {f1:.4f}")
print(f"ROC AUC Score: {roc_auc:.4f}")
# Out:
# Accuracy: 0.7154
# Precision: 0.7586
# Recall: 0.8250
# F1-Score: 0.7904
# ROC AUC Score: 0.6683

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Define labels for the confusion matrix
labels = ['Actual N', 'Actual Y']
cmap = 'Blues'

# Visualize the confusion matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap=cmap, xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix for Decision Tree Classifier')
plt.show()

print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[22 21]
#  [14 66]]

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# Create a figure with a suitable size
plt.figure(figsize=(20, 15))

# Visualize the trained Decision Tree Classifier
plot_tree(dtc,
          filled=True,
          feature_names=X.columns.tolist(),
          class_names=['No Loan', 'Loan'], # Assuming 0 for 'No Loan' and 1 for 'Loan' based on previous mapping
          rounded=True,
          fontsize=10)

# Add a title to the plot
plt.title('Decision Tree Structure', fontsize=15)

# Display the plot
plt.show()
print("Decision Tree structure visualized.")
# Out:
# Decision Tree structure visualized.
