# %% [markdown]
# <a href="https://colab.research.google.com/github/deorebhumika06/ai-projects/blob/main/4%20project%20of%20cleaning%20part.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pf
import matplotlib.pyplot as pla
import seaborn as sns

# %%
df=pf.read_csv("/content/indian_ecommerce_pricing_revenue_growth_36_months (1).csv")
df.head()
# Out:
#      order_id  order_date           state     zone            category  \
# 0  ORD0000001  2023-01-31     West Bengal     East             Fashion
# 1  ORD0000002  2023-01-31         Gujarat     West    Sports & Fitness
# 2  ORD0000003  2023-01-31       Delhi NCR    North  Grocery Essentials
# 3  ORD0000004  2023-01-31  Madhya Pradesh  Central            Footwear
# 4  ORD0000005  2023-01-31         Haryana    North             Fashion
#
#   brand_type customer_gender  customer_age  base_price  discount_percent  \
# 0       Mass            Male            28     1810.89             65.00
# 1       Mass            Male            19     5678.15             50.83
# 2       Mass            Male            25      169.98             35.26
# 3       Mass          Female            30     3244.91             61.94
# 4    Premium          Female            33      697.44             48.27
#
#    final_price  units_sold    revenue sales_event competition_intensity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30600 entries, 0 to 30599
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               30600 non-null  object
#  1   order_date             30600 non-null  object
#  2   state                  30600 non-null  object
#  3   zone                   30600 non-null  object
#  4   category               30600 non-null  object
#  5   brand_type             30600 non-null  object
#  6   customer_gender        30600 non-null  object
#  7   customer_age           30600 non-null  int64
#  8   base_price             30600 non-null  float64
#  9   discount_percent       30600 non-null  float64
#  10  final_price            30600 non-null  float64
#  11  units_sold             30600 non-null  int64
#  12  revenue                30600 non-null  float64
#  13  sales_event            30600 non-null  object
# ...

# %%
df.describe().sum()/len(df)*100
# Out:
# customer_age         100.766147
# base_price           204.579283
# discount_percent     100.763725
# final_price          182.295563
# units_sold           100.983943
# revenue             4062.402933
# dtype: float64

# %%
df.isnull().sum()
# Out:
# order_id                 0
# order_date               0
# state                    0
# zone                     0
# category                 0
# brand_type               0
# customer_gender          0
# customer_age             0
# base_price               0
# discount_percent         0
# final_price              0
# units_sold               0
# revenue                  0
# sales_event              0
# competition_intensity    0
# inventory_pressure       0
# dtype: int64

# %%
df.shape
# Out:
# (30600, 16)

# %%
df[df.duplicated].shape
# Out:
# (0, 16)

# %%
import re

# %%
for col in df.columns:
  if df[col].nunique():
    print(col)
    print(df[col])
    print("_"*50)
# Out:
# order_id
# 0        ORD0000001
# 1        ORD0000002
# 2        ORD0000003
# 3        ORD0000004
# 4        ORD0000005
#             ...
# 30595    ORD0030596
# 30596    ORD0030597
# 30597    ORD0030598
# 30598    ORD0030599
# 30599    ORD0030600
# Name: order_id, Length: 30600, dtype: object
# __________________________________________________
# order_date
# 0        2023-01-31
# 1        2023-01-31
# 2        2023-01-31
# 3        2023-01-31
# 4        2023-01-31
#             ...
# 30595    2025-12-31
# 30596    2025-12-31
# 30597    2025-12-31
# 30598    2025-12-31
# 30599    2025-12-31
# Name: order_date, Length: 30600, dtype: object
# __________________________________________________
# state
# 0           West Bengal
# 1               Gujarat
# 2             Delhi NCR
# 3        Madhya Pradesh
# 4               Haryana
#               ...
# 30595     Uttar Pradesh
# 30596           Haryana
# 30597            Odisha
# 30598       West Bengal
# 30599       Maharashtra
# ...

# %%
df.dropna(subset=('state'),inplace=True)

# %%
df.dropna()
# Out:
#          order_id  order_date           state     zone            category  \
# 0      ORD0000001  2023-01-31     West Bengal     East             Fashion
# 1      ORD0000002  2023-01-31         Gujarat     West    Sports & Fitness
# 2      ORD0000003  2023-01-31       Delhi NCR    North  Grocery Essentials
# 3      ORD0000004  2023-01-31  Madhya Pradesh  Central            Footwear
# 4      ORD0000005  2023-01-31         Haryana    North             Fashion
# ...           ...         ...             ...      ...                 ...
# 30595  ORD0030596  2025-12-31   Uttar Pradesh    North   Premium Lifestyle
# 30596  ORD0030597  2025-12-31         Haryana    North            Footwear
# 30597  ORD0030598  2025-12-31          Odisha     East            Footwear
# 30598  ORD0030599  2025-12-31     West Bengal     East    Sports & Fitness
# 30599  ORD0030600  2025-12-31     Maharashtra     West            Footwear
#
# ...

# %%
import re

# %%
def export_city(state):
  state_no=re.findall('[0-9]+',str(state))
  if len(state_no)>0:
    return int(state_no[0])
  else:
    return None
df['state']=df['state'].apply(export_city)

# %%
df.isnull().sum()
# Out:
# order_id                     0
# order_date                   0
# state                    30600
# zone                         0
# category                     0
# brand_type                   0
# customer_gender              0
# customer_age                 0
# base_price                   0
# discount_percent             0
# final_price                  0
# units_sold                   0
# revenue                      0
# sales_event                  0
# competition_intensity        0
# inventory_pressure           0
# dtype: int64

# %%
df['state'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df=df.dropna(subset=('state'),inplace=True)

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, state, zone, category, brand_type, customer_gender, customer_age, base_price, discount_percent, final_price, units_sold, revenue, sales_event, competition_intensity, inventory_pressure]
# Index: []

# %%
df['state']=df['state'].fillna(0)

# %%
df.isnull().sum()
# Out:
# order_id                 0
# order_date               0
# state                    0
# zone                     0
# category                 0
# brand_type               0
# customer_gender          0
# customer_age             0
# base_price               0
# discount_percent         0
# final_price              0
# units_sold               0
# revenue                  0
# sales_event              0
# competition_intensity    0
# inventory_pressure       0
# dtype: int64

# %%
df['order_id']=df['order_id'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               0 non-null      int64
#  1   order_date             0 non-null      object
#  2   state                  0 non-null      object
#  3   zone                   0 non-null      object
#  4   category               0 non-null      object
#  5   brand_type             0 non-null      object
#  6   customer_gender        0 non-null      object
#  7   customer_age           0 non-null      int64
#  8   base_price             0 non-null      float64
#  9   discount_percent       0 non-null      float64
#  10  final_price            0 non-null      float64
#  11  units_sold             0 non-null      int64
#  12  revenue                0 non-null      float64
#  13  sales_event            0 non-null      object
#  14  competition_intensity  0 non-null      object
# ...

# %%
df['order_date']=pf.to_datetime(df['order_date'])

# %%
df['customer_gender']=df['customer_gender'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               0 non-null      int64
#  1   order_date             0 non-null      datetime64[ns]
#  2   state                  0 non-null      object
#  3   zone                   0 non-null      object
#  4   category               0 non-null      object
#  5   brand_type             0 non-null      object
#  6   customer_gender        0 non-null      category
#  7   customer_age           0 non-null      int64
#  8   base_price             0 non-null      float64
#  9   discount_percent       0 non-null      float64
#  10  final_price            0 non-null      float64
#  11  units_sold             0 non-null      int64
#  12  revenue                0 non-null      float64
#  13  sales_event            0 non-null      object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   order_id               0 non-null      int64
#  1   order_date             0 non-null      datetime64[ns]
#  2   state                  0 non-null      object
#  3   zone                   0 non-null      object
#  4   category               0 non-null      object
#  5   brand_type             0 non-null      object
#  6   customer_gender        0 non-null      category
#  7   customer_age           0 non-null      int64
#  8   base_price             0 non-null      float64
#  9   discount_percent       0 non-null      float64
#  10  final_price            0 non-null      float64
#  11  units_sold             0 non-null      int64
#  12  revenue                0 non-null      float64
#  13  sales_event            0 non-null      object
# ...

# %%
df.isnull().sum()
# Out:
# order_id                 0
# order_date               0
# state                    0
# zone                     0
# category                 0
# brand_type               0
# customer_gender          0
# customer_age             0
# base_price               0
# discount_percent         0
# final_price              0
# units_sold               0
# revenue                  0
# sales_event              0
# competition_intensity    0
# inventory_pressure       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# order_id                          int64
# order_date               datetime64[ns]
# state                            object
# zone                             object
# category                         object
# brand_type                       object
# customer_gender                category
# customer_age                      int64
# base_price                      float64
# discount_percent                float64
# final_price                     float64
# units_sold                        int64
# revenue                         float64
# sales_event                      object
# competition_intensity            object
# inventory_pressure               object
# dtype: object

# %%
df['brand_type'].unique()
# Out:
# array([], dtype=object)

# %%
df['brand_type'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, state, zone, category, brand_type, customer_gender, customer_age, base_price, discount_percent, final_price, units_sold, revenue, sales_event, competition_intensity, inventory_pressure]
# Index: []

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'state', 'zone', 'category', 'brand_type',
#        'customer_gender', 'customer_age', 'base_price', 'discount_percent',
#        'final_price', 'units_sold', 'revenue', 'sales_event',
#        'competition_intensity', 'inventory_pressure'],
#       dtype='object')

# %%
df.shape
# Out:
# (0, 16)

# %%
df.shape
df['brand_type'].head()
df['brand_type'].isnull().sum()
df.columns
# Out:
# Index(['order_id', 'order_date', 'state', 'zone', 'category', 'brand_type',
#        'customer_gender', 'customer_age', 'base_price', 'discount_percent',
#        'final_price', 'units_sold', 'revenue', 'sales_event',
#        'competition_intensity', 'inventory_pressure'],
#       dtype='object')

# %%
df['brand_type'].unique()
# Out:
# array([], dtype=object)

# %%
df.describe().sum()
# Out:
# order_id            0.0
# order_date            0
# customer_age        0.0
# base_price          0.0
# discount_percent    0.0
# final_price         0.0
# units_sold          0.0
# revenue             0.0
# dtype: object

# %%
df.shape
# Out:
# (0, 16)

# %%
import pandas as pf

# %%
df=pf.read_csv('/content/indian_ecommerce_pricing_revenue_growth_36_months (1).csv')
df.shape
# Out:
# (30600, 16)

# %%
df.fillna(method='ffill',inplace=True)
# Out:
# /tmp/ipykernel_9319/4116506308.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill',inplace=True)

# %%
df.isnull().sum()
# Out:
# order_id                 0
# order_date               0
# state                    0
# zone                     0
# category                 0
# brand_type               0
# customer_gender          0
# customer_age             0
# base_price               0
# discount_percent         0
# final_price              0
# units_sold               0
# revenue                  0
# sales_event              0
# competition_intensity    0
# inventory_pressure       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# order_id                  object
# order_date                object
# state                     object
# zone                      object
# category                  object
# brand_type                object
# customer_gender           object
# customer_age               int64
# base_price               float64
# discount_percent         float64
# final_price              float64
# units_sold                 int64
# revenue                  float64
# sales_event               object
# competition_intensity     object
# inventory_pressure        object
# dtype: object

# %%
df['order_id'] = df['order_id'].str.replace('ORD', '').astype(int)

# %%
df['order_date']=pf.to_datetime(df['order_date'])

# %%
df.dtypes
# Out:
# order_id                          int64
# order_date               datetime64[ns]
# state                            object
# zone                             object
# category                         object
# brand_type                       object
# customer_gender                  object
# customer_age                      int64
# base_price                      float64
# discount_percent                float64
# final_price                     float64
# units_sold                        int64
# revenue                         float64
# sales_event                      object
# competition_intensity            object
# inventory_pressure               object
# dtype: object

# %%
df['customer_age'].unique()
# Out:
# array([28, 19, 25, 30, 33, 47, 23, 45, 40, 22, 21, 34, 29, 53, 44, 31, 27,
#        46, 49, 18, 36, 20, 41, 37, 48, 52, 26, 51, 63, 24, 43, 32, 35, 39,
#        42, 61, 64, 38, 59, 57, 50, 55, 54, 62, 58, 65, 60, 56])
