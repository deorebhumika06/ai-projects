# %% [markdown]
# <a href="https://colab.research.google.com/github/deorebhumika06/ai-projects/blob/main/cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/Salary_dataset.csv")
df
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       30 non-null     int64
#  1   YearsExperience  30 non-null     float64
#  2   Salary           30 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 852.0 bytes

# %%
df.describe()
# Out:
#        Unnamed: 0  YearsExperience         Salary
# count   30.000000        30.000000      30.000000
# mean    14.500000         5.413333   76004.000000
# std      8.803408         2.837888   27414.429785
# min      0.000000         1.200000   37732.000000
# 25%      7.250000         3.300000   56721.750000
# 50%     14.500000         4.800000   65238.000000
# 75%     21.750000         7.800000  100545.750000
# max     29.000000        10.600000  122392.000000

# %%
df['YearsExperience'].value_counts()
# Out:
# YearsExperience
# 4.1     2
# 3.3     2
# 1.2     1
# 1.4     1
# 2.1     1
# 1.6     1
# 3.0     1
# 2.3     1
# 3.1     1
# 3.8     1
# 4.0     1
# 4.2     1
# 4.6     1
# 5.0     1
# 5.2     1
# 5.4     1
# 6.0     1
# 6.1     1
# 6.9     1
# 7.2     1
# 8.0     1
# 8.3     1
# 8.8     1
# 9.1     1
# 9.6     1
# 9.7     1
# 10.4    1
# 10.6    1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.histplot(df['YearsExperience'],kde=True)
plt.title("salary tabel")
plt.xlabel("over all salary")
plt.ylabel("per month")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.boxplot(x=df['YearsExperience'])
plt.title("salary tabel")
plt.xlabel("over all salary")
plt.ylabel("per month")
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
df.hist(bins=50,figsize=(20,15))
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.boxplot(figsize=(20,15))
plt.tight_layout()
plt.show()

# %%
#train-test

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
df=pd.read_csv("/content/indian_ecommerce_pricing_revenue_growth_36_months (1).csv")
x=df.drop("final_price" , axis=1)
y=df['final_price']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=45)
print("x label",x_train.shape)
print("y label",y_train.shape)
# Out:
# x label (24480, 15)
# y label (24480,)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
df=pd.read_csv("/content/indian_ecommerce_pricing_revenue_growth_36_months (1).csv")
x=df.drop("final_price",axis=1)
y=df["final_price"]
x_train , x_test , y_train , y_test=train_test_split(x,y,test_size=0.20)
print("x label",x_test.shape)
print("y label",y_test.shape)
# Out:
# x label (6120, 15)
# y label (6120,)

# %%
import pandas as pd
df=pd.read_csv("/content/indian_ecommerce_pricing_revenue_growth_36_months (1).csv")
df.head()
# Out:
#      order_id  order_date           state     zone            category  \
# 0  ORD0000001  2023-01-31     West Bengal     East             Fashion
# 1  ORD0000002  2023-01-31         Gujarat     West    Sports & Fitness
# 2  ORD0000003  2023-01-31       Delhi NCR    North  Grocery Essentials
# 3  ORD0000004  2023-01-31  Madhya Pradesh  Central            Footwear
# 4  ORD0000005  2023-01-31         Haryana    North             Fashion
#
#   brand_type customer_gender  customer_age  base_price  discount_percent  \
# 0       Mass            Male            28     1810.89             65.00
# 1       Mass            Male            19     5678.15             50.83
# 2       Mass            Male            25      169.98             35.26
# 3       Mass          Female            30     3244.91             61.94
# 4    Premium          Female            33      697.44             48.27
#
#    final_price  units_sold    revenue sales_event competition_intensity  \
# ...

# %%
df = df.rename(columns={'brand_type': 'Brand_type'})
print(df.columns)
# Out:
# Index(['order_id', 'order_date', 'state', 'zone', 'category', 'Brand_type',
#        'customer_gender', 'customer_age', 'base_price', 'discount_percent',
#        'final_price', 'units_sold', 'revenue', 'sales_event',
#        'competition_intensity', 'inventory_pressure'],
#       dtype='object')

# %%
print(df['brand_type'].value_counts())
# Out:
# brand_type
# Mass       22970
# Premium     7630
# Name: count, dtype: int64

# %%
df['category'].value_counts()
# Out:
# category
# Beauty & Personal Care    3961
# Sports & Fitness          3870
# Footwear                  3831
# Fashion                   3831
# Electronics               3813
# Grocery Essentials        3776
# Home & Living             3769
# Premium Lifestyle         3749
# Name: count, dtype: int64

# %%
df['category']=df['category'].replace({"Electronics":"Grosari"})

# %%
df['category'].value_counts()
