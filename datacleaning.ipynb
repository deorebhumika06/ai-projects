# %% [markdown]
# <a href="https://colab.research.google.com/github/deorebhumika06/ai-projects/blob/main/datacleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_csv("/content/healthcare_dataset.csv (1).zip")
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  55500.000000    55500.000000  55500.000000
# mean      51.539459    25539.316097    301.134829
# std       19.602454    14211.454431    115.243069
# min       13.000000    -2008.492140    101.000000
# 25%       35.000000    13241.224652    202.000000
# 50%       52.000000    25538.069376    302.000000
# 75%       68.000000    37820.508436    401.000000
# max       89.000000    52764.276736    500.000000

# %%
df.isnull()
# Out:
#         Name    Age  Gender  Blood Type  Medical Condition  Date of Admission  \
# 0      False  False   False       False              False              False
# 1      False  False   False       False              False              False
# 2      False  False   False       False              False              False
# 3      False  False   False       False              False              False
# 4      False  False   False       False              False              False
# ...      ...    ...     ...         ...                ...                ...
# 55495  False  False   False       False              False              False
# 55496  False  False   False       False              False              False
# 55497  False  False   False       False              False              False
# 55498  False  False   False       False              False              False
# 55499  False  False   False       False              False              False
#
# ...

# %%
df['Doctor'].value_counts()
# Out:
# Doctor
# Michael Smith      27
# John Smith         22
# Robert Smith       22
# Michael Johnson    20
# James Smith        20
#                    ..
# Keith Ortiz         1
# Timothy Chapman     1
# Terri Collins       1
# Jill Jacobson       1
# Scott Coleman       1
# Name: count, Length: 40341, dtype: int64

# %%
df['Hospital'].unique()
# Out:
# array(['Sons and Miller', 'Kim Inc', 'Cook PLC', ...,
#        'Guzman Jones and Graves,', 'and Williams, Brown Mckenzie',
#        'Moreno Murphy, Griffith and'], dtype=object)

# %%
df[df['Medical Condition']!='Room Number']
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
df[df['Name']!='Gender']
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.hist(bins=30,figsize=(10,5))
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(11,2))
plt.subplot(1,2,1)
sns.histplot(df['Medical Condition'],kde=True)
plt.title('hosptal data')
plt.xlabel('desese')
plt.ylabel('age')
plt.tight_layout()
plt.show()
plt.subplot(1,2,2)
sns.histplot(df['Medical Condition'],kde=True)
plt.title('overall hospital data')
plt.xlabel('desese')
plt.ylabel('age of peshant')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
df=pd.read_csv('/content/healthcare_dataset.csv (1).zip')
x=df.drop(['Medical Condition'],axis=1)
y=df['Medical Condition']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
print("x axis",x_test.shape)
print("y axis",y_test.shape)
# Out:
# x axis (11100, 14)
# y axis (11100,)

# %%
df['Gender']=df['Gender'].replace('Male','M')
df['Gender']=df['Gender'].replace('Female','F')

# %%
df['Gender'].value_counts()
# Out:
# Gender
# 0    27774
# 1    27726
# Name: count, dtype: int64

# %%
df[df['Doctor']=='Matthew Smith']
# Out:
#                     Name  Age Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30      0         B-            Cancer
# 1266       LEaH martINez   84      1         O-      Hypertension
# 5027     jarED GIlleSPIe   85      1         O+      Hypertension
# 6040        thomas lopez   54      0         O-            Asthma
# 6679        mElviN HAnNa   64      0         A-           Obesity
# 9104      DoNNA ROBersoN   34      0         B+         Arthritis
# 18300   dEANna HENDeRSOn   34      0         A-            Asthma
# 19184         pAuL BaIrd   73      1         O-           Obesity
# 19972        bARRY OrtiZ   26      0         A-         Arthritis
# 23969  KiMbeRLy sTEPHeNS   38      0        AB+           Obesity
# 30413      SydnEy PATTon   39      1         O-      Hypertension
# 34253       StacY fRanCO   23      1         B-      Hypertension
# 34737     alEXaNDeR caSe   56      1         O+            Cancer
# ...

# %%
df['Doctor']=df['Doctor'].replace('Matthew Smith','bhumika deore')
df['Doctor'].unique()
df['Doctor'].value_counts()
df[df['Doctor'] == 'bhumika deore']
# Out:
#                     Name  Age Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30      0         B-            Cancer
# 1266       LEaH martINez   84      1         O-      Hypertension
# 5027     jarED GIlleSPIe   85      1         O+      Hypertension
# 6040        thomas lopez   54      0         O-            Asthma
# 6679        mElviN HAnNa   64      0         A-           Obesity
# 9104      DoNNA ROBersoN   34      0         B+         Arthritis
# 18300   dEANna HENDeRSOn   34      0         A-            Asthma
# 19184         pAuL BaIrd   73      1         O-           Obesity
# 19972        bARRY OrtiZ   26      0         A-         Arthritis
# 23969  KiMbeRLy sTEPHeNS   38      0        AB+           Obesity
# 30413      SydnEy PATTon   39      1         O-      Hypertension
# 34253       StacY fRanCO   23      1         B-      Hypertension
# 34737     alEXaNDeR caSe   56      1         O+            Cancer
# ...

# %%
df[df['Doctor'] == 'bhumika deore']
# Out:
#                     Name  Age Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30      0         B-            Cancer
# 1266       LEaH martINez   84      1         O-      Hypertension
# 5027     jarED GIlleSPIe   85      1         O+      Hypertension
# 6040        thomas lopez   54      0         O-            Asthma
# 6679        mElviN HAnNa   64      0         A-           Obesity
# 9104      DoNNA ROBersoN   34      0         B+         Arthritis
# 18300   dEANna HENDeRSOn   34      0         A-            Asthma
# 19184         pAuL BaIrd   73      1         O-           Obesity
# 19972        bARRY OrtiZ   26      0         A-         Arthritis
# 23969  KiMbeRLy sTEPHeNS   38      0        AB+           Obesity
# 30413      SydnEy PATTon   39      1         O-      Hypertension
# 34253       StacY fRanCO   23      1         B-      Hypertension
# 34737     alEXaNDeR caSe   56      1         O+            Cancer
# ...

# %%
df['Doctor']=df['Doctor'].replace('Tiffany Mitchell','vatsalya deore')
df[df['Doctor'] == 'vatsalya deore']
# Out:
#           Name  Age Gender Blood Type Medical Condition Date of Admission  \
# 2  DaNnY sMitH   76      1         A-           Obesity        2022-09-22
#
#            Doctor  Hospital Insurance Provider  Billing Amount  Room Number  \
# 2  vatsalya deore  Cook PLC              Aetna    27955.096079          205
#
#   Admission Type Discharge Date Medication Test Results
# 2      Emergency     2022-10-07    Aspirin       Normal

# %%
import pandas as pd
df=pd.read_csv('/content/train_u6lujuX_CVtuZ9i (1).csv')
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
import matplotlib.pyplot as plt
df.hist(bins=50 , figsize=(20,5))
plt.show()
plt.tight_layout()

# %%
df['Education']=df['Education'].replace('Graduate','a')
df[df['Education']=='a']
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 0    LP001002    Male      No          0         a            No
# 1    LP001003    Male     Yes          1         a            No
# 2    LP001005    Male     Yes          0         a           Yes
# 4    LP001008    Male      No          0         a            No
# 5    LP001011    Male     Yes          2         a           Yes
# ..        ...     ...     ...        ...       ...           ...
# 609  LP002978  Female      No          0         a            No
# 610  LP002979    Male     Yes         3+         a            No
# 611  LP002983    Male     Yes          1         a            No
# 612  LP002984    Male     Yes          2         a            No
# 613  LP002990  Female      No          0         a           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         NaN             360.0
# ...
